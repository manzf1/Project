# %% [markdown]
# #**Social Media Influence**
#
# The data we will be using is base on a survey. The survey asked the person their age range, how long they stay online than they intended to, does the time they spend online affect their grades, or if their job performance are affected, how often they check their social media, do they stay awake for being online, how long they spend online, etc. The features taken from the survey are:
#
#
#
# *   Age
# *   Education
# *   Social_media_time_in_hours
# *   Field
# *   Settlement
# *   New_vs_Old_user
# *   QOL
# *   IAT
#
#
# ##Features:
#
# Age:
# age range goes from 18-22, 23-25, 26-28, above 28, bellow 18.
#
# Social_media_time_in_hours:
# less than 1, more than 3, 1-2, 2-3.
#
# Education:
# 10th grade,
# 12th grade,
# Bachelor's degree,
# Diploma,
# Master's degree.
#
# Field:
# Art,
# Psychology,
# Sociology,
# Designing,
# Education Teaching,
# Engineering,
# Finance,
# Fine Arts,
# Law,
# Management,
# Mass-communication,
# Medical,
# Nursing,
# Pharmacy,
# Tourism management.
#
# Settlement:
# Rural,
# Urban.
#
# New_vs_Old_User:
# 2 years ago,
# 3 years ago,
# 4 years ago or higher,
# less than an year ago.
#
# QOL:
# QOL in this data was measure in the survey by asking the people questions like:
#
# * How often do you find that you stay online longer than you intended?
#
# * How often do your grades or school work suffer because of the amount of time you spend online?
#
# * How often does your job performance or productivity suffer because of the social media?
#
# QOL scale is measure from 2 to 10

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import missingno as msno
import seaborn as sns


df = pd.read_csv (r'https://raw.githubusercontent.com/AnaSal023/BCS109/main/final_Data.csv')

#Show the beginning of the data
df.head(11)
# Out:
#     index       Age Social_media_time_in_hours  ...        New_vs_Old_user IAT QOL
# 0       1  Above 28                         >3  ...  4 years ago or higher   2   8
# 1       2  Above 28                         >3  ...  4 years ago or higher   2   8
# 2       3  Above 28                         >3  ...  4 years ago or higher   2   8
# 3       4  Above 28                         >3  ...  4 years ago or higher   2   8
# 4       5     18-22                     2 to 3  ...            3 years ago   2   8
# 5       6     18-22                     2 to 3  ...            3 years ago   2   8
# 6       7     18-22                     2 to 3  ...            3 years ago   2   8
# 7       8     18-22                     2 to 3  ...            3 years ago   2   8
# 8       9  Above 28                         <1  ...  4 years ago or higher   3   3
# 9      10  Above 28                         <1  ...  4 years ago or higher   3   3
# ...

# %%
#Create a second copy of the data 
df_original = df.copy()

# %%
#Drop index column
df = df.drop(['index'], axis=1)


df.head(10)
# Out:
#         Age Social_media_time_in_hours  ... IAT QOL
# 0  Above 28                         >3  ...   2   8
# 1  Above 28                         >3  ...   2   8
# 2  Above 28                         >3  ...   2   8
# 3  Above 28                         >3  ...   2   8
# 4     18-22                     2 to 3  ...   2   8
# 5     18-22                     2 to 3  ...   2   8
# 6     18-22                     2 to 3  ...   2   8
# 7     18-22                     2 to 3  ...   2   8
# 8  Above 28                         <1  ...   3   3
# 9  Above 28                         <1  ...   3   3
#
# [10 rows x 8 columns]

# %%
#We are checking the mean of 'Social_media_time_in_hours' 
average_time_spent = df_cac['Social_media_time_in_hours'].mean()

print("The average time in hours in social media is: ", average_time_spent)
# Out:
# The average time in hours in social media is:  1.3630573248407643

# %%
#Minimum for all columns
df.min()
# Out:
# Age                                                    18-22
# Social_media_time_in_hours                            1 to 2
# Education                                         10th grade
# Field                         Arts, Psychology and Sociology
# Settlement                                             Rural
# New_vs_Old_user                                  2 years ago
# IAT                                                        2
# QOL                                                        2
# dtype: object

# %%
#Maximum for all columns
df.max()
# Out:
# Age                                        below 18
# Social_media_time_in_hours                       >3
# Education                           Master's Degree
# Field                            Tourism management
# Settlement                                    Urban
# New_vs_Old_user               less than an year ago
# IAT                                              35
# QOL                                              10
# dtype: object

# %%
#Check if we have any empty data
df.isna().sum()
# Out:
# Age                           0
# Social_media_time_in_hours    0
# Education                     0
# Field                         0
# Settlement                    0
# New_vs_Old_user               0
# IAT                           0
# QOL                           0
# dtype: int64

# %%
#Check how many unique values we have in each column
df.nunique()
# Out:
# Age                            5
# Social_media_time_in_hours     4
# Education                      5
# Field                         13
# Settlement                     2
# New_vs_Old_user                4
# IAT                           32
# QOL                            9
# dtype: int64

# %%
#Check the type of each feature
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256 entries, 0 to 1255
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         1256 non-null   object
#  1   Social_media_time_in_hours  1256 non-null   object
#  2   Education                   1256 non-null   object
#  3   Field                       1256 non-null   object
#  4   Settlement                  1256 non-null   object
#  5   New_vs_Old_user             1256 non-null   object
#  6   IAT                         1256 non-null   int64
#  7   QOL                         1256 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 78.6+ KB

# %%
#Check fo nulls
df.isnull().sum()
# Out:
# Age                           0
# Social_media_time_in_hours    0
# Education                     0
# Field                         0
# Settlement                    0
# New_vs_Old_user               0
# IAT                           0
# QOL                           0
# dtype: int64

# %%
#Using value_counts to plot Social media time (in hours)
plt.figure(figsize=(20,10))
df['Social_media_time_in_hours'].value_counts().plot(kind='bar', fontsize=1)

# %%
#output the individual parts of the categorical data to view it
print(df['Field'].value_counts())
# Out:
# Engineering                       288
# Finance                           244
# Management                        204
# Arts, Psychology and Sociology    196
# Designing                         116
# Education Teaching                 60
# Fine Arts                          48
# Mass-communication                 32
# Medical                            28
# Pharmacy                           16
# Tourism management                 12
# Nursing                             8
# Law                                 4
# Name: Field, dtype: int64

# %%
print(df['Age'].value_counts())
# Out:
# 18-22       440
# 23-25       368
# Above 28    216
# 26-28       200
# below 18     32
# Name: Age, dtype: int64

# %%
print(df['New_vs_Old_user'].value_counts())
# Out:
# 4 years ago or higher    940
# 3 years ago              144
# 2 years ago              124
# less than an year ago     48
# Name: New_vs_Old_user, dtype: int64

# %%
#use value_counts to plot the different types of Fields

plt.figure(figsize=(8,5))
df['Field'].value_counts().plot(kind='bar', fontsize = 8)

# %%
#use value_counts to plot the different ages

plt.figure(figsize=(8,5))
df['Age'].value_counts().plot(kind='bar', fontsize = 8)

# %%
#use value_counts to plot New_vs_Old_user

plt.figure(figsize=(8,5))
df['New_vs_Old_user'].value_counts().plot(kind='bar', fontsize = 8)

# %% [markdown]
# #LabelEncoder
#
# Since we have categorical data, we will not be able to make reasonable comparisons unless we first convert it into numbers.  Of course, converting it doesn't make it good for regressions, but perhaps there is some information we can drag out of it nevertheless.

# %% [markdown]
# We are converting the 'Age' into numerical data. The age range will be converted to integers.
#
# Ranges:
#
#
# *   18-22 = 0
# *   26-28 = 2
# *   23-25 = 1
# *   Above 28 = 3
# *   Bellow 18 = 4

# %%
from sklearn import preprocessing

#create a second data set
df_SI = df.copy()

#set up LabelEncoding
le = preprocessing.LabelEncoder()
interim = le.fit_transform(df_SI['Age'])

#place it back into a dataframe
interim = pd.DataFrame(interim)
interim.columns = ['Age']

#place the new values back in df_SI
df_SI['Age'] = interim['Age']

#check
df_SI.head(10)
# Out:
#    Age Social_media_time_in_hours  ... IAT QOL
# 0    3                         >3  ...   2   8
# 1    3                         >3  ...   2   8
# 2    3                         >3  ...   2   8
# 3    3                         >3  ...   2   8
# 4    0                     2 to 3  ...   2   8
# 5    0                     2 to 3  ...   2   8
# 6    0                     2 to 3  ...   2   8
# 7    0                     2 to 3  ...   2   8
# 8    3                         <1  ...   3   3
# 9    3                         <1  ...   3   3
#
# [10 rows x 8 columns]

# %% [markdown]
# Fields:
#
#
# *   Art, Psychology, and Sociology = 0
# *   Designing = 1
# *   Education Teaching = 2
# *   Engineering = 3
# *   Finance = 4
# *   Fine Arts = 5
# *   Law = 6
# *   Management = 7
# *   Mass-communication = 8
# *   Medical = 9
# *   Nursing = 10
# *   Pharmacy = 11
# *   Tourism management = 12

# %%
#set up LabelEncoding
le = preprocessing.LabelEncoder()
interim = le.fit_transform(df_SI['Field'])

#place it back into a dataframe
interim = pd.DataFrame(interim)
interim.columns = ['Field']

#place the new values back in df_SI
df_SI['Field'] = interim['Field']

#check
df_SI.head(10)
# Out:
#    Age Social_media_time_in_hours  ... IAT  QOL
# 0    3                         >3  ...   2    8
# 1    3                         >3  ...   2    8
# 2    3                         >3  ...   2    8
# 3    3                         >3  ...   2    8
# 4    0                     2 to 3  ...   2    8
# 5    0                     2 to 3  ...   2    8
# 6    0                     2 to 3  ...   2    8
# 7    0                     2 to 3  ...   2    8
# 8    3                         <1  ...   3    3
# 9    3                         <1  ...   3    3
#
# [10 rows x 8 columns]

# %% [markdown]
# New_vs_Old_user:
#
# *  2 years ago = 0
# *  3 years ago = 1
# *  4 years ago or higher = 2
# *  less than an year ago = 3

# %%
#set up LabelEncoding
le = preprocessing.LabelEncoder()
interim = le.fit_transform(df_SI['New_vs_Old_user'])

#place it back into a dataframe
interim = pd.DataFrame(interim)
interim.columns = ['New_vs_Old_user']

#place the new values back in df_SI
df_SI['New_vs_Old_user'] = interim['New_vs_Old_user']

#check
df_SI.head(10)
# Out:
#    Age Social_media_time_in_hours          Education  ...  New_vs_Old_user IAT  QOL
# 0    3                         >3         12th grade  ...                2   2    8
# 1    3                         >3         12th grade  ...                2   2    8
# 2    3                         >3         12th grade  ...                2   2    8
# 3    3                         >3         12th grade  ...                2   2    8
# 4    0                     2 to 3  Bachelor's Degree  ...                1   2    8
# 5    0                     2 to 3  Bachelor's Degree  ...                1   2    8
# 6    0                     2 to 3  Bachelor's Degree  ...                1   2    8
# 7    0                     2 to 3  Bachelor's Degree  ...                1   2    8
# 8    3                         <1    Master's Degree  ...                2   3    3
# 9    3                         <1    Master's Degree  ...                2   3    3
#
# [10 rows x 8 columns]

# %% [markdown]
# Social_media_time_in_hours:
#
# *  1 to 2 = 0
# *  2 to 3 = 1
# *  less than 1 = 2
# *  more than 3 = 3

# %%
#set up LabelEncoding
le = preprocessing.LabelEncoder()
interim = le.fit_transform(df_SI['Social_media_time_in_hours'])

#place it back into a dataframe
interim = pd.DataFrame(interim)
interim.columns = ['Social_media_time_in_hours']

#place the new values back in df_SI
df_SI['Social_media_time_in_hours'] = interim['Social_media_time_in_hours']

#check
df_SI.head(10)
# Out:
#    Age  Social_media_time_in_hours  ... IAT  QOL
# 0    3                           3  ...   2    8
# 1    3                           3  ...   2    8
# 2    3                           3  ...   2    8
# 3    3                           3  ...   2    8
# 4    0                           1  ...   2    8
# 5    0                           1  ...   2    8
# 6    0                           1  ...   2    8
# 7    0                           1  ...   2    8
# 8    3                           2  ...   3    3
# 9    3                           2  ...   3    3
#
# [10 rows x 8 columns]

# %% [markdown]
# Education:
#
#
# *   10th grade = 0
# *   12th grade = 1
# *   Bachelor's degree = 2
# *   Diploma = 3
# *   Master's degree = 4

# %%
#set up LabelEncoding
le = preprocessing.LabelEncoder()
interim = le.fit_transform(df_SI['Education'])

#place it back into a dataframe
interim = pd.DataFrame(interim)
interim.columns = ['Education']

#place the new values back in df_SI
df_SI['Education'] = interim['Education']

#check
df_SI.head(10)
# Out:
#    Age  Social_media_time_in_hours  Education  ...  New_vs_Old_user IAT  QOL
# 0    3                           3          1  ...                2   2    8
# 1    3                           3          1  ...                2   2    8
# 2    3                           3          1  ...                2   2    8
# 3    3                           3          1  ...                2   2    8
# 4    0                           1          2  ...                1   2    8
# 5    0                           1          2  ...                1   2    8
# 6    0                           1          2  ...                1   2    8
# 7    0                           1          2  ...                1   2    8
# 8    3                           2          4  ...                2   3    3
# 9    3                           2          4  ...                2   3    3
#
# [10 rows x 8 columns]

# %% [markdown]
# Settlement:
#
# *  Rural = 0
# *  Urban = 1

# %%
#set up LabelEncoding
le = preprocessing.LabelEncoder()
interim = le.fit_transform(df_SI['Settlement'])

#place it back into a dataframe
interim = pd.DataFrame(interim)
interim.columns = ['Settlement']

#place the new values back in df_SI
df_SI['Settlement'] = interim['Settlement']
df_SI = df_SI.drop(['IAT'], axis =1)

df_cac = df_SI
df_S = df_SI
#check
df_SI.head(10)
# Out:
#    Age  Social_media_time_in_hours  Education  ...  Settlement  New_vs_Old_user  QOL
# 0    3                           3          1  ...           0                2    8
# 1    3                           3          1  ...           0                2    8
# 2    3                           3          1  ...           0                2    8
# 3    3                           3          1  ...           0                2    8
# 4    0                           1          2  ...           1                1    8
# 5    0                           1          2  ...           1                1    8
# 6    0                           1          2  ...           1                1    8
# 7    0                           1          2  ...           1                1    8
# 8    3                           2          4  ...           1                2    3
# 9    3                           2          4  ...           1                2    3
#
# [10 rows x 7 columns]

# %%
#Check the data statistics
df_SI.describe()
# Out:
#                Age  Social_media_time_in_hours  ...  New_vs_Old_user          QOL
# count  1256.000000                 1256.000000  ...      1256.000000  1256.000000
# mean      1.229299                    1.363057  ...         1.726115     7.089172
# std       1.172718                    1.174241  ...         0.687848     1.783057
# min       0.000000                    0.000000  ...         0.000000     2.000000
# 25%       0.000000                    0.000000  ...         2.000000     6.000000
# 50%       1.000000                    1.000000  ...         2.000000     7.000000
# 75%       2.000000                    3.000000  ...         2.000000     8.000000
# max       4.000000                    3.000000  ...         3.000000    10.000000
#
# [8 rows x 7 columns]

# %%
#graph the number of values per row in a bar chart
msno.bar(df_SI);

# %% [markdown]
# With the bar chart above we can visualize see that there is no missing data

# %% [markdown]
# ##**Correlation Matrix**

# %%
corrMatrix = df_SI.corr()
plt.figure(figsize=(10,7))
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# In the heatmap above we can see that Social_media_time_in_hours is more affected by New_vs_Old_user just by 0.0048
#
# We can see that there are no strong correaltions between Social_media_time_in_hours. There are some other correlations the highest being 0.3 between Field and Education, Eduaction and Age.
#
# And that New_vs_Old_user is mostly affected by Age and Education

# %% [markdown]
# Next we will look at the distributions of our data to identify the shape of the distribution as well as identify any potential outliers.

# %% [markdown]
# ##**Histogram**

# %%
#Analying data with charts
df_SI.hist(bins=50, figsize=(12,8))
plt.show()

# %% [markdown]
# The charts above show us the the information of each feature and the value counts in each of them

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error


X = df_SI[['Social_media_time_in_hours']]
y = df_SI['New_vs_Old_user']
#Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = .25, random_state=1)

# %% [markdown]
# ##**Decision Tree Classifier**

# %%
#Load libraries

import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

#Features
X = df_SI
#Target variable
y = df_SI['Social_media_time_in_hours']
#Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = .25, random_state=1)

# %% [markdown]
# ###Buidling Decision Tree Model

# %%
#create decision tree classifier object
clf = DecisionTreeClassifier()

#train decision tree classifier
clf = clf.fit(X_train,y_train)

#predict the response for the test dataset
y_pred = clf.predict(X_test)

# %% [markdown]
# ###Evaluating Model

# %%
#model accuracy, how ofte is the classifer correct?
print("Accuracy: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  1.0

# %% [markdown]
# We get 1.0 accuracy which is not good, the problem might be that our data was converted to numerical and this model does not work for it since it considers the data to be not practically possible to be process for this model.

# %% [markdown]
# ##Random Forest

# %% [markdown]
# ###Features and Targets and Convert Date to Arrays

# %%
# Use numpy to convert to arrays
import numpy as np
# Labels are the values we want to predict
labels = np.array(df_SI['Social_media_time_in_hours'])
# Remove the labels from the features
features= df_SI.drop('Social_media_time_in_hours', axis = 1)
# Saving feature names for later use
feature_list = list(df_SI.columns)
# Convert to numpy array
features = np.array(features)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
Training_Features_Shape: (1080, 14)
Training_Labels_Shape: (261,14)
Testing_Features_Shape: (87, 14)
Testing_Labels_Shape: (87,14)
# Out:
# Training Features Shape: (942, 6)
# Training Labels Shape: (942,)
# Testing Features Shape: (314, 6)
# Testing Labels Shape: (314,)

# %% [markdown]
# ##Baseline prediction

# %%
# The baseline predictions are the historical averages
baseline_preds = test_features[:, feature_list.index('Social_media_time_in_hours')]
# Baseline errors, and display average baseline error
baseline_errors = abs(baseline_preds - test_labels)
print('Average baseline error: ', round(np.mean(baseline_errors), 2))
Average_baseline_error: 5.06
# Out:
# Average baseline error:  1.54

# %% [markdown]
# ###**Train Model**

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);

# %% [markdown]
# ###Make Preditions on the Test Set

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2))
Mean_Absolute_Error: 3.83
# Out:
# Mean Absolute Error: 0.37

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
Accuracy: 93.99

# %% [markdown]
# ##**Single Decision Tree**

# %%
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tree = rf.estimators_[5]
# Export the image to a dot file

export_graphviz(tree, out_file = 'tree.dot', feature_names=feature_list, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree.dot')
# Write graph to a png file
graph.write_png('tree.png')

# %%
from IPython.display import Image
Image(filename = 'tree.png')

# %% [markdown]
# We'll see the model in a smaller scale

# %% [markdown]
# ###Small Decision Tree

# %%
# Limit depth of tree to 3 levels
rf_small = RandomForestRegressor(n_estimators=10, max_depth = 3)
rf_small.fit(train_features, train_labels)
# Extract the small tree
tree_small = rf_small.estimators_[5]
# Save the tree as a png image

export_graphviz(tree_small, out_file = 'small_tree.dot', feature_names = df_SI.columns, rounded = True, precision = 1)
(graph, ) = pydot.graph_from_dot_file('small_tree.dot')
graph.write_png('small_tree.png')

# %% [markdown]
# New_vs_Old_user = Variable and Value split Node on
#
# square_error = Mean Squared Error od Node
#
# samples = Number of data points in this node
#
# value = Prediction (in degrees) for all data points in node

# %%
from IPython.display import Image
Image(filename = 'small_tree.png')

# %% [markdown]
# Based on this tree we can make a predition for any new data point.
#
# We can see that the time in social media (New_vs_Old_user) is affected by QOL, then settlement leaving with a value of 0.9 for time in social media. By all of this we can see why New_vs_Old _user is the one with more correlation to Social_media_time_in_hours.

# %% [markdown]
# ##**Importance of QOL in the users**
#
# We show that the feature that affect Social_media_time_in_hours is New_vs_Old_user, but now we will also measure the what affects the quality of life (QOL) of social media users.

# %% [markdown]
# ###Simple bar plot of the feature importances to illustrate the disparities in the significance of the variables

# %%
# Import matplotlib for plotting and use magic command for Jupyter Notebooks
import matplotlib.pyplot as plt
# %matplotlib inline
# Set the style
plt.style.use('fivethirtyeight')
# list of x locations for plotting
importances = list(rf.feature_importances_)
x_values = list(range(len(importances)))
# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')
# Tick labels for x axis
plt.xticks(x_values, feature_list, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %% [markdown]
# In the chart above we see what other features affect QOL (quality of life), the first one being New_vs_Old_user, then Education, Age, Social_media_time_in_hours, Settlement, and lastly field

# %% [markdown]
# ###**More Correlation**
#
# The chart bellow show us the dependency of the features with Social_media_time_in_hours. The feature with less dependency and more correlation like shown above with the heat map is New_vs_Old_user.

# %%
#using yellowbrick for visualizations
from yellowbrick.target import FeatureCorrelation

target = df_SI['Social_media_time_in_hours']
features = df_SI.drop('Social_media_time_in_hours',axis=1).copy()
feature_names = list(features.columns)

visualizer = FeatureCorrelation(labels=feature_names,method='pearson')
visualizer.fit(features,target)
visualizer.poof()

# %% [markdown]
# From the chart bellow we use Mutual Information and we can see that Education, QOL, and Age are the more dependables features for Social_media_time_in_hours

# %%
#find mutual-information
#here we use regression, but there is also
#visualizer = FeatureCorrelation(method='mutual_info-classification', feature_names=features, sort=True)

visualizer = FeatureCorrelation(method='mutual_info-regression',features_names=feature_names,sort=True)
visualizer.fit(features,target)
visualizer.poof()

# %% [markdown]
# ##**Chi-Square Analysis**

# %%
#we will be looking for social media usage
X = df_SI.drop('Social_media_time_in_hours',1)
y = df_SI['Social_media_time_in_hours']

# %%
print(X.head(10))
# Out:
#    Age  Education  Field  Settlement  New_vs_Old_user  QOL
# 0    3          1      0           0                2    8
# 1    3          1      0           0                2    8
# 2    3          1      0           0                2    8
# 3    3          1      0           0                2    8
# 4    0          2      3           1                1    8
# 5    0          2      3           1                1    8
# 6    0          2      3           1                1    8
# 7    0          2      3           1                1    8
# 8    3          4      2           1                2    3
# 9    3          4      2           1                2    3

# %%
#chi-square analysis
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X, y)

# %%
feature_score = pd.DataFrame()

for i in range(X.shape[1]):
    new = pd.DataFrame({'Features' : X.columns[i],
                        'Score' : fit.scores_[i]}, index=[i])
    
    feature_score = pd.concat([feature_score, new])

# %%
#we will select those 
feature_score
# Out:
#           Features      Score
# 0              Age  18.483617
# 1        Education   8.297178
# 2            Field  33.558694
# 3       Settlement   0.667478
# 4  New_vs_Old_user   0.775386
# 5              QOL   7.868767

# %% [markdown]
# ###Columns Names
#
# 0 = Age
#
# 1 = Education
#
# 2 = Field
#
# 3 = New_vs_Old_user

# %% [markdown]
# The Chi-Square Model show us the features that correlated more to Social_media_time_in_hours. As before we have New_vs_Old_user, we also have Age, Education, and Field. Those being the 4 more important features in the analysis

# %%
X_new = fit.transform(X)
X_new = pd.DataFrame(X_new)

X_new.head(10)
# Out:
#    0  1  2  3
# 0  3  1  0  8
# 1  3  1  0  8
# 2  3  1  0  8
# 3  3  1  0  8
# 4  0  2  3  8
# 5  0  2  3  8
# 6  0  2  3  8
# 7  0  2  3  8
# 8  3  4  2  3
# 9  3  4  2  3

# %% [markdown]
# #**Summary**
#
# In, summary we transformed our data to numerical to use it for different models but just a couple had shown a solution and to prove if our hypothesis is correct or wrong.
#
#
# We have found out that the Age and Field are not the ones that affected someone using social media but New_vs_Old_user. Someone that has been using social media the longest is highly to continue using it and they will use it longer during the day than someone that is new in it. We also see how the QOL is affected by the time being in social, their age, and education. Social has a great effect on users, especially if they spend many time on it. QOL in this data was measure in the survey by asking the people questions like:
#
# * How often do you find that you stay online longer than you intended?
#
# * How often do your grades or school work suffer because of the amount of time you spend online?
#
# * How often does your job performance or productivity suffer because of the social media?
#
# * How often do you lose sleep due to being online?
#
# * How often do you feel depressed, moody, or nervous when you are off-line, which goes away once you are back online?
#
# Taking all the analysis from this data we got to see that the time spent in social media affects the QOL of the people. Our hypothesis said that the age and the field of someone are the variables that correlates more in their social media usage but just some models show their correlation in it. It can be said that our hypothesis was wrong but the Chi-Square Analysis model prove that it does have some effect on the social media time usage.
